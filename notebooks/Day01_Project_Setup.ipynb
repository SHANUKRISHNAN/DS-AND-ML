# %% [markdown]
# # Day01 Project Setup

# %%
from pathlib import Path
print('Project root:', Path.cwd())
print('Python environment is ready when this cell runs successfully.')
# Out:
# Project root: c:\Users\Kamali\OneDrive\Documents\Desktop\EcoTwin_Urban_Carbon_Dispersal_Complete\notebooks
# Python environment is ready when this cell runs successfully.
