# %% [markdown]
# # Day02 Dataset Collection

# %%
import pandas as pd
from pathlib import Path
p=Path('../data/raw/EcoTwin_dataset_raw.csv')
df=pd.read_csv(p)
print('Shape:',df.shape)
print(df.head())
print(df.dtypes)
# Out:
# Shape: (1500, 16)
#           timestamp   zone_id   latitude   longitude  wind_speed_ms  \
# 0  01-01-2026 00:00  Zone_007  37.715376 -122.449398           2.03
# 1  01-01-2026 01:00  Zone_004  37.840584 -122.497101           7.77
# 2  01-01-2026 02:00  Zone_008  37.803183 -122.481345           1.98
# 3  01-01-2026 03:00  Zone_005  37.710176 -122.437954           7.15
# 4  01-01-2026 04:00  Zone_007  37.745145 -122.426070           8.47
#
#    wind_direction_deg  temperature_c  humidity_pct  \
# 0                51.9           15.7          51.9
# 1               273.2           33.1          68.1
# 2               180.2           24.8          50.5
# 3               328.2           19.5          35.7
# 4                52.8           22.5          44.5
#
#    traffic_emission_rate_kg_h  industrial_emission_rate_kg_h  \
# 0                      338.02                        1142.36
# 1                      272.66                         610.25
# ...
