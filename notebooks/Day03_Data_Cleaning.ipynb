# %% [markdown]
# # Day03 Data Cleaning

# %%
# %run ../src/day03_cleaning.py
# Out:
# EcoTwin Day 3 - Data Cleaning Summary
# Initial shape: 1500 rows x 16 columns
# Missing values before cleaning: 0
# Duplicate rows before cleaning: 0
# Final shape: 1500 rows x 16 columns
# Timestamp parsing: successful
# Outliers: flagged in outputs/reports/outlier_report.csv; not deleted automatically.
# Saved: C:\Users\Kamali\OneDrive\Documents\Desktop\EcoTwin_Urban_Carbon_Dispersal_Complete\data\processed\EcoTwin_clean.csv
# C:\Users\Kamali\OneDrive\Documents\Desktop\EcoTwin_Urban_Carbon_Dispersal_Complete\src\day03_cleaning.py:18: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# ...
