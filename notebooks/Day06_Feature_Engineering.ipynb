# %% [markdown]
# # Day06 Feature Engineering

# %%
# %run ../src/day06_feature_engineering.py
# Out:
# Created: C:\Users\Kamali\OneDrive\Documents\Desktop\EcoTwin_Urban_Carbon_Dispersal_Complete\data\processed\EcoTwin_features.csv
#  hour  day  month  dayofweek  is_weekend traffic_level wind_category
#     0    1      1          3           0        Medium        Medium
#     1    1      1          3           0        Medium          High
#     2    1      1          3           0          High           Low
#     3    1      1          3           0          High          High
#     4    1      1          3           0           Low          High
#     5    1      1          3           0           Low          High
#     6    1      1          3           0        Medium          High
#     7    1      1          3           0           Low          High
#     8    1      1          3           0           Low          High
#     9    1      1          3           0          High          High
